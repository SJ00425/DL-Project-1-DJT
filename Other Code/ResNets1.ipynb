# %% [markdown]
# # ResNet Model

# %%
'''ResNet in PyTorch.

For Pre-activation ResNet, see 'preact_resnet.py'.

Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Deep Residual Learning for Image Recognition. arXiv:1512.03385
'''
import torch
import torch.nn as nn
import torch.nn.functional as F


class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(
            in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion *
                               planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def ResNet10():
    return ResNet(BasicBlock, [1,1,1,1])

def ResNet12():
    return ResNet(BasicBlock, [1,2,1,1])

def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])


def ResNet34():
    return ResNet(BasicBlock, [3, 4, 6, 3])


def ResNet50():
    return ResNet(Bottleneck, [3, 4, 6, 3])


def ResNet101():
    return ResNet(Bottleneck, [3, 4, 23, 3])


def ResNet152():
    return ResNet(Bottleneck, [3, 8, 36, 3])


def test():
    net = ResNet18()
    y = net(torch.randn(1, 3, 32, 32))
    print(y.size())

# test()

# %% [markdown]
# # Pre_Activation ResNet Model

# %%
'''Pre-activation ResNet in PyTorch.

Reference:
[1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun
    Identity Mappings in Deep Residual Networks. arXiv:1603.05027
'''
import torch
import torch.nn as nn
import torch.nn.functional as F


class PreActBlock(nn.Module):
    '''Pre-activation version of the BasicBlock.'''
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(PreActBlock, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)

        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
            )

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        out += shortcut
        return out


class PreActBottleneck(nn.Module):
    '''Pre-activation version of the original Bottleneck module.'''
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(PreActBottleneck, self).__init__()
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)

        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False)
            )

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        out = self.conv3(F.relu(self.bn3(out)))
        out += shortcut
        return out


class PreActResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(PreActResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out

def PreActResNet10():
    return PreActResNet(PreActBlock, [1,1,1,1])

def PreActResNet12():
    return PreActResNet(PreActBlock, [1,2,1,1])

def PreActResNet18():
    return PreActResNet(PreActBlock, [2,2,2,2])

def PreActResNet34():
    return PreActResNet(PreActBlock, [3,4,6,3])

def PreActResNet50():
    return PreActResNet(PreActBottleneck, [3,4,6,3])

def PreActResNet101():
    return PreActResNet(PreActBottleneck, [3,4,23,3])

def PreActResNet152():
    return PreActResNet(PreActBottleneck, [3,8,36,3])


def test():
    net = PreActResNet18()
    y = net((torch.randn(1,3,32,32)))
    print(y.size())

# test()

# %% [markdown]
# # Model Parameters num

# %%
import torch
# from utils import progress_bar
from torchsummary import summary

model = PreActResNet152()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)  

summary(model, input_size=(3,32, 32))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3          [-1, 256, 32, 32]          16,384
#             Conv2d-4           [-1, 64, 32, 32]           4,096
#        BatchNorm2d-5           [-1, 64, 32, 32]             128
#             Conv2d-6           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-7           [-1, 64, 32, 32]             128
#             Conv2d-8          [-1, 256, 32, 32]          16,384
#   PreActBottleneck-9          [-1, 256, 32, 32]               0
#       BatchNorm2d-10          [-1, 256, 32, 32]             512
#            Conv2d-11           [-1, 64, 32, 32]          16,384
#       BatchNorm2d-12           [-1, 64, 32, 32]             128
#            Conv2d-13           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-14           [-1, 64, 32, 32]             128
#            Conv2d-15          [-1, 256, 32, 32]          16,384
#  PreActBottleneck-16          [-1, 256, 32, 32]               0
#       BatchNorm2d-17          [-1, 256, 32, 32]             512
#            Conv2d-18           [-1, 64, 32, 32]          16,384
#       BatchNorm2d-19           [-1, 64, 32, 32]             128
#            Conv2d-20           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-21           [-1, 64, 32, 32]             128
#            Conv2d-22          [-1, 256, 32, 32]          16,384
#  PreActBottleneck-23          [-1, 256, 32, 32]               0
#       BatchNorm2d-24          [-1, 256, 32, 32]             512
#            Conv2d-25          [-1, 512, 16, 16]         131,072
#            Conv2d-26          [-1, 128, 32, 32]          32,768
#       BatchNorm2d-27          [-1, 128, 32, 32]             256
#            Conv2d-28          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-29          [-1, 128, 16, 16]             256
#            Conv2d-30          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-31          [-1, 512, 16, 16]               0
#       BatchNorm2d-32          [-1, 512, 16, 16]           1,024
#            Conv2d-33          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-34          [-1, 128, 16, 16]             256
#            Conv2d-35          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-36          [-1, 128, 16, 16]             256
#            Conv2d-37          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-38          [-1, 512, 16, 16]               0
#       BatchNorm2d-39          [-1, 512, 16, 16]           1,024
#            Conv2d-40          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-41          [-1, 128, 16, 16]             256
#            Conv2d-42          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-43          [-1, 128, 16, 16]             256
#            Conv2d-44          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-45          [-1, 512, 16, 16]               0
#       BatchNorm2d-46          [-1, 512, 16, 16]           1,024
#            Conv2d-47          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-48          [-1, 128, 16, 16]             256
#            Conv2d-49          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-50          [-1, 128, 16, 16]             256
#            Conv2d-51          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-52          [-1, 512, 16, 16]               0
#       BatchNorm2d-53          [-1, 512, 16, 16]           1,024
#            Conv2d-54          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-55          [-1, 128, 16, 16]             256
#            Conv2d-56          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-57          [-1, 128, 16, 16]             256
#            Conv2d-58          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-59          [-1, 512, 16, 16]               0
#       BatchNorm2d-60          [-1, 512, 16, 16]           1,024
#            Conv2d-61          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-62          [-1, 128, 16, 16]             256
#            Conv2d-63          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-64          [-1, 128, 16, 16]             256
#            Conv2d-65          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-66          [-1, 512, 16, 16]               0
#       BatchNorm2d-67          [-1, 512, 16, 16]           1,024
#            Conv2d-68          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-69          [-1, 128, 16, 16]             256
#            Conv2d-70          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-71          [-1, 128, 16, 16]             256
#            Conv2d-72          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-73          [-1, 512, 16, 16]               0
#       BatchNorm2d-74          [-1, 512, 16, 16]           1,024
#            Conv2d-75          [-1, 128, 16, 16]          65,536
#       BatchNorm2d-76          [-1, 128, 16, 16]             256
#            Conv2d-77          [-1, 128, 16, 16]         147,456
#       BatchNorm2d-78          [-1, 128, 16, 16]             256
#            Conv2d-79          [-1, 512, 16, 16]          65,536
#  PreActBottleneck-80          [-1, 512, 16, 16]               0
#       BatchNorm2d-81          [-1, 512, 16, 16]           1,024
#            Conv2d-82           [-1, 1024, 8, 8]         524,288
#            Conv2d-83          [-1, 256, 16, 16]         131,072
#       BatchNorm2d-84          [-1, 256, 16, 16]             512
#            Conv2d-85            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-86            [-1, 256, 8, 8]             512
#            Conv2d-87           [-1, 1024, 8, 8]         262,144
#  PreActBottleneck-88           [-1, 1024, 8, 8]               0
#       BatchNorm2d-89           [-1, 1024, 8, 8]           2,048
#            Conv2d-90            [-1, 256, 8, 8]         262,144
#       BatchNorm2d-91            [-1, 256, 8, 8]             512
#            Conv2d-92            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-93            [-1, 256, 8, 8]             512
#            Conv2d-94           [-1, 1024, 8, 8]         262,144
#  PreActBottleneck-95           [-1, 1024, 8, 8]               0
#       BatchNorm2d-96           [-1, 1024, 8, 8]           2,048
#            Conv2d-97            [-1, 256, 8, 8]         262,144
#       BatchNorm2d-98            [-1, 256, 8, 8]             512
#            Conv2d-99            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-100            [-1, 256, 8, 8]             512
#           Conv2d-101           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-102           [-1, 1024, 8, 8]               0
#      BatchNorm2d-103           [-1, 1024, 8, 8]           2,048
#           Conv2d-104            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-105            [-1, 256, 8, 8]             512
#           Conv2d-106            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-107            [-1, 256, 8, 8]             512
#           Conv2d-108           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-109           [-1, 1024, 8, 8]               0
#      BatchNorm2d-110           [-1, 1024, 8, 8]           2,048
#           Conv2d-111            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-112            [-1, 256, 8, 8]             512
#           Conv2d-113            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-114            [-1, 256, 8, 8]             512
#           Conv2d-115           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-116           [-1, 1024, 8, 8]               0
#      BatchNorm2d-117           [-1, 1024, 8, 8]           2,048
#           Conv2d-118            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-119            [-1, 256, 8, 8]             512
#           Conv2d-120            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-121            [-1, 256, 8, 8]             512
#           Conv2d-122           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-123           [-1, 1024, 8, 8]               0
#      BatchNorm2d-124           [-1, 1024, 8, 8]           2,048
#           Conv2d-125            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-126            [-1, 256, 8, 8]             512
#           Conv2d-127            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-128            [-1, 256, 8, 8]             512
#           Conv2d-129           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-130           [-1, 1024, 8, 8]               0
#      BatchNorm2d-131           [-1, 1024, 8, 8]           2,048
#           Conv2d-132            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-133            [-1, 256, 8, 8]             512
#           Conv2d-134            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-135            [-1, 256, 8, 8]             512
#           Conv2d-136           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-137           [-1, 1024, 8, 8]               0
#      BatchNorm2d-138           [-1, 1024, 8, 8]           2,048
#           Conv2d-139            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-140            [-1, 256, 8, 8]             512
#           Conv2d-141            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-142            [-1, 256, 8, 8]             512
#           Conv2d-143           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-144           [-1, 1024, 8, 8]               0
#      BatchNorm2d-145           [-1, 1024, 8, 8]           2,048
#           Conv2d-146            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-147            [-1, 256, 8, 8]             512
#           Conv2d-148            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-149            [-1, 256, 8, 8]             512
#           Conv2d-150           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-151           [-1, 1024, 8, 8]               0
#      BatchNorm2d-152           [-1, 1024, 8, 8]           2,048
#           Conv2d-153            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-154            [-1, 256, 8, 8]             512
#           Conv2d-155            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-156            [-1, 256, 8, 8]             512
#           Conv2d-157           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-158           [-1, 1024, 8, 8]               0
#      BatchNorm2d-159           [-1, 1024, 8, 8]           2,048
#           Conv2d-160            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-161            [-1, 256, 8, 8]             512
#           Conv2d-162            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-163            [-1, 256, 8, 8]             512
#           Conv2d-164           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-165           [-1, 1024, 8, 8]               0
#      BatchNorm2d-166           [-1, 1024, 8, 8]           2,048
#           Conv2d-167            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-168            [-1, 256, 8, 8]             512
#           Conv2d-169            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-170            [-1, 256, 8, 8]             512
#           Conv2d-171           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-172           [-1, 1024, 8, 8]               0
#      BatchNorm2d-173           [-1, 1024, 8, 8]           2,048
#           Conv2d-174            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-175            [-1, 256, 8, 8]             512
#           Conv2d-176            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-177            [-1, 256, 8, 8]             512
#           Conv2d-178           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-179           [-1, 1024, 8, 8]               0
#      BatchNorm2d-180           [-1, 1024, 8, 8]           2,048
#           Conv2d-181            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-182            [-1, 256, 8, 8]             512
#           Conv2d-183            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-184            [-1, 256, 8, 8]             512
#           Conv2d-185           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-186           [-1, 1024, 8, 8]               0
#      BatchNorm2d-187           [-1, 1024, 8, 8]           2,048
#           Conv2d-188            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-189            [-1, 256, 8, 8]             512
#           Conv2d-190            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-191            [-1, 256, 8, 8]             512
#           Conv2d-192           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-193           [-1, 1024, 8, 8]               0
#      BatchNorm2d-194           [-1, 1024, 8, 8]           2,048
#           Conv2d-195            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-196            [-1, 256, 8, 8]             512
#           Conv2d-197            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-198            [-1, 256, 8, 8]             512
#           Conv2d-199           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-200           [-1, 1024, 8, 8]               0
#      BatchNorm2d-201           [-1, 1024, 8, 8]           2,048
#           Conv2d-202            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-203            [-1, 256, 8, 8]             512
#           Conv2d-204            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-205            [-1, 256, 8, 8]             512
#           Conv2d-206           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-207           [-1, 1024, 8, 8]               0
#      BatchNorm2d-208           [-1, 1024, 8, 8]           2,048
#           Conv2d-209            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-210            [-1, 256, 8, 8]             512
#           Conv2d-211            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-212            [-1, 256, 8, 8]             512
#           Conv2d-213           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-214           [-1, 1024, 8, 8]               0
#      BatchNorm2d-215           [-1, 1024, 8, 8]           2,048
#           Conv2d-216            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-217            [-1, 256, 8, 8]             512
#           Conv2d-218            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-219            [-1, 256, 8, 8]             512
#           Conv2d-220           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-221           [-1, 1024, 8, 8]               0
#      BatchNorm2d-222           [-1, 1024, 8, 8]           2,048
#           Conv2d-223            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-224            [-1, 256, 8, 8]             512
#           Conv2d-225            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-226            [-1, 256, 8, 8]             512
#           Conv2d-227           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-228           [-1, 1024, 8, 8]               0
#      BatchNorm2d-229           [-1, 1024, 8, 8]           2,048
#           Conv2d-230            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-231            [-1, 256, 8, 8]             512
#           Conv2d-232            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-233            [-1, 256, 8, 8]             512
#           Conv2d-234           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-235           [-1, 1024, 8, 8]               0
#      BatchNorm2d-236           [-1, 1024, 8, 8]           2,048
#           Conv2d-237            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-238            [-1, 256, 8, 8]             512
#           Conv2d-239            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-240            [-1, 256, 8, 8]             512
#           Conv2d-241           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-242           [-1, 1024, 8, 8]               0
#      BatchNorm2d-243           [-1, 1024, 8, 8]           2,048
#           Conv2d-244            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-245            [-1, 256, 8, 8]             512
#           Conv2d-246            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-247            [-1, 256, 8, 8]             512
#           Conv2d-248           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-249           [-1, 1024, 8, 8]               0
#      BatchNorm2d-250           [-1, 1024, 8, 8]           2,048
#           Conv2d-251            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-252            [-1, 256, 8, 8]             512
#           Conv2d-253            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-254            [-1, 256, 8, 8]             512
#           Conv2d-255           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-256           [-1, 1024, 8, 8]               0
#      BatchNorm2d-257           [-1, 1024, 8, 8]           2,048
#           Conv2d-258            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-259            [-1, 256, 8, 8]             512
#           Conv2d-260            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-261            [-1, 256, 8, 8]             512
#           Conv2d-262           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-263           [-1, 1024, 8, 8]               0
#      BatchNorm2d-264           [-1, 1024, 8, 8]           2,048
#           Conv2d-265            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-266            [-1, 256, 8, 8]             512
#           Conv2d-267            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-268            [-1, 256, 8, 8]             512
#           Conv2d-269           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-270           [-1, 1024, 8, 8]               0
#      BatchNorm2d-271           [-1, 1024, 8, 8]           2,048
#           Conv2d-272            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-273            [-1, 256, 8, 8]             512
#           Conv2d-274            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-275            [-1, 256, 8, 8]             512
#           Conv2d-276           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-277           [-1, 1024, 8, 8]               0
#      BatchNorm2d-278           [-1, 1024, 8, 8]           2,048
#           Conv2d-279            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-280            [-1, 256, 8, 8]             512
#           Conv2d-281            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-282            [-1, 256, 8, 8]             512
#           Conv2d-283           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-284           [-1, 1024, 8, 8]               0
#      BatchNorm2d-285           [-1, 1024, 8, 8]           2,048
#           Conv2d-286            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-287            [-1, 256, 8, 8]             512
#           Conv2d-288            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-289            [-1, 256, 8, 8]             512
#           Conv2d-290           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-291           [-1, 1024, 8, 8]               0
#      BatchNorm2d-292           [-1, 1024, 8, 8]           2,048
#           Conv2d-293            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-294            [-1, 256, 8, 8]             512
#           Conv2d-295            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-296            [-1, 256, 8, 8]             512
#           Conv2d-297           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-298           [-1, 1024, 8, 8]               0
#      BatchNorm2d-299           [-1, 1024, 8, 8]           2,048
#           Conv2d-300            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-301            [-1, 256, 8, 8]             512
#           Conv2d-302            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-303            [-1, 256, 8, 8]             512
#           Conv2d-304           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-305           [-1, 1024, 8, 8]               0
#      BatchNorm2d-306           [-1, 1024, 8, 8]           2,048
#           Conv2d-307            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-308            [-1, 256, 8, 8]             512
#           Conv2d-309            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-310            [-1, 256, 8, 8]             512
#           Conv2d-311           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-312           [-1, 1024, 8, 8]               0
#      BatchNorm2d-313           [-1, 1024, 8, 8]           2,048
#           Conv2d-314            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-315            [-1, 256, 8, 8]             512
#           Conv2d-316            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-317            [-1, 256, 8, 8]             512
#           Conv2d-318           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-319           [-1, 1024, 8, 8]               0
#      BatchNorm2d-320           [-1, 1024, 8, 8]           2,048
#           Conv2d-321            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-322            [-1, 256, 8, 8]             512
#           Conv2d-323            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-324            [-1, 256, 8, 8]             512
#           Conv2d-325           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-326           [-1, 1024, 8, 8]               0
#      BatchNorm2d-327           [-1, 1024, 8, 8]           2,048
#           Conv2d-328            [-1, 256, 8, 8]         262,144
#      BatchNorm2d-329            [-1, 256, 8, 8]             512
#           Conv2d-330            [-1, 256, 8, 8]         589,824
#      BatchNorm2d-331            [-1, 256, 8, 8]             512
#           Conv2d-332           [-1, 1024, 8, 8]         262,144
# PreActBottleneck-333           [-1, 1024, 8, 8]               0
#      BatchNorm2d-334           [-1, 1024, 8, 8]           2,048
#           Conv2d-335           [-1, 2048, 4, 4]       2,097,152
#           Conv2d-336            [-1, 512, 8, 8]         524,288
#      BatchNorm2d-337            [-1, 512, 8, 8]           1,024
#           Conv2d-338            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-339            [-1, 512, 4, 4]           1,024
#           Conv2d-340           [-1, 2048, 4, 4]       1,048,576
# PreActBottleneck-341           [-1, 2048, 4, 4]               0
#      BatchNorm2d-342           [-1, 2048, 4, 4]           4,096
#           Conv2d-343            [-1, 512, 4, 4]       1,048,576
#      BatchNorm2d-344            [-1, 512, 4, 4]           1,024
#           Conv2d-345            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-346            [-1, 512, 4, 4]           1,024
#           Conv2d-347           [-1, 2048, 4, 4]       1,048,576
# PreActBottleneck-348           [-1, 2048, 4, 4]               0
#      BatchNorm2d-349           [-1, 2048, 4, 4]           4,096
#           Conv2d-350            [-1, 512, 4, 4]       1,048,576
#      BatchNorm2d-351            [-1, 512, 4, 4]           1,024
#           Conv2d-352            [-1, 512, 4, 4]       2,359,296
#      BatchNorm2d-353            [-1, 512, 4, 4]           1,024
#           Conv2d-354           [-1, 2048, 4, 4]       1,048,576
# PreActBottleneck-355           [-1, 2048, 4, 4]               0
#           Linear-356                   [-1, 10]          20,490
# ================================================================
# Total params: 58,144,842
# Trainable params: 58,144,842
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 138.13
# Params size (MB): 221.80
# Estimated Total Size (MB): 359.94
# ----------------------------------------------------------------

# %% [markdown]
# # Load Data
# two transformers for train data,

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import pickle
import numpy as np
import os
from PIL import Image
import multiprocessing
from torch.utils.data import random_split


# Unpickle function
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

class CIFARDataset(Dataset):
    def __init__(self, data_files, transform=None):
        self.data = []
        self.labels = []
        self.transform = transform

        for file in data_files:
            batch = unpickle(file)
            images = batch[b'data']
            labels = batch[b'labels']

            images = images.reshape(-1, 3, 32, 32).astype(np.uint8)  # Keep uint8 (0-255)
            self.data.append(images)
            self.labels.extend(labels)

        self.data = np.vstack(self.data)
        self.labels = np.array(self.labels)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        image = self.data[idx]  # Still a NumPy array (H, W, C)
        label = self.labels[idx]

        # Convert NumPy array to PIL image before applying transforms
        image = Image.fromarray(np.transpose(image, (1, 2, 0)))  # Convert (C, H, W) -> (H, W, C)
        
        if self.transform:
            image = self.transform(image)  # Now transform works correctly

        return image, label




# Define paths
data_dir = "deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py"  # Change this if your path is different
train_files = [os.path.join(data_dir, f"data_batch_{i}") for i in range(1, 6)]
test_file = os.path.join(data_dir, "test_batch")

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  # Randomly crop 32x32 with padding of 4
    transforms.RandomHorizontalFlip(),  # Flip the image horizontally with 50% probability
    transforms.RandomRotation(10),
    # transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1, hue=0.05),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),  # Convert image to a PyTorch tensor
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),  # Normalize with CIFAR-10 mean/std
    transforms.RandomErasing(p=0.5, scale=(0.02, 0.2), ratio=(0.3, 3.3)),
])

# transform_train = transforms.Compose([
#     transforms.RandomCrop(32, padding=4),
#     transforms.RandomHorizontalFlip(),
#     transforms.ToTensor(),
#     transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
# ])

"""
Q: Do we need trans-test?

"""
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])


# Automatically determine optimal num_workers
num_workers = min(8, multiprocessing.cpu_count() // 2)  # Use half of CPU cores, max 8
pin_memory = True if torch.cuda.is_available() else False  # Enable only if using GPU



# Load datasets
train_dataset = CIFARDataset(train_files, transform=transform_train)
test_dataset = CIFARDataset([test_file], transform=transform_test)

train_size = int(0.9 * len(train_dataset))  
val_size = len(train_dataset) - train_size 
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
# test_loader = DataLoader(test_dataset, batch_size=128, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# %%
# Check Data
# data = unpickle("deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_1" )
# print(data.keys())  
# print(len(data[b'labels']))

# %% [markdown]
# # Model Initialization

# %%
from torch.optim.lr_scheduler import SequentialLR, LinearLR, CosineAnnealingLR
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize model
model = PreActResNet152().to(device)


# Training function with validation
def train(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs=200, patience=10, save_dir="checkpoints"):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    best_val_acc = 0.0  # Store the best validation accuracy
    early_stop_counter = 0  # Early stopping counter
    best_val_loss = float("inf") 

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            correct += predicted.eq(labels).sum().item()
            total += labels.size(0)

        scheduler.step()  # Update learning rate

        # Compute training loss and accuracy
        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct / total

        # Compute validation loss and accuracy
        val_loss, val_acc = validate(model, val_loader, criterion)

        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, "
              f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")

        # # Save the best model based on validation accuracy
        # if val_acc > best_val_acc:
        #     best_val_acc = val_acc
        #     torch.save(model.state_dict(), os.path.join(save_dir, "best_model.pth"))
        #     print("Best model saved!")

        # # Early stopping logic
        # if val_loss > train_loss:
        #     early_stop_counter += 1
        #     if early_stop_counter >= patience:
        #         print("Early stopping triggered!")
        #         break

        # --- Save the best model based on val_acc ---
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), os.path.join(save_dir, "best_model.pth"))
            print(f"Best model saved (based on val_acc = {val_acc:.2f}%)!")

        # --- Early Stopping based on val_loss ---
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            early_stop_counter = 0
        else:
            early_stop_counter += 1
            if early_stop_counter >= patience:
                print("Early stopping triggered! Validation loss did not improve.")
                break

# Validation function
def validate(model, val_loader, criterion):
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, predicted = outputs.max(1)
            correct += predicted.eq(labels).sum().item()
            total += labels.size(0)

    avg_val_loss = val_loss / len(val_loader)
    val_acc = 100 * correct / total
    model.train()  # Switch back to training mode
    return avg_val_loss, val_acc

# Test function
def test(model, test_loader):
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = outputs.max(1)
            correct += predicted.eq(labels).sum().item()
            total += labels.size(0)

    print(f"Test Accuracy: {100 * correct / total:.2f}%")


# Set hyperparameters
"""
when epochs = 350
warmup_total_iters = 10
"""
epochs = 200
warmup_total_iters = 5
patience = 2000  # Number of epochs to wait before early stopping
save_dir = "checkpoints"

# Define loss function
criterion = nn.CrossEntropyLoss()
# Define optimizer

# optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4, nesterov=True)
# optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)

# Define learning rate scheduler
# scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# Learning rate scheduler with warmup
warmup_scheduler = LinearLR(optimizer, start_factor=0.1, total_iters=warmup_total_iters)
cosine_scheduler = CosineAnnealingLR(optimizer, T_max=epochs-warmup_total_iters)
scheduler = SequentialLR(optimizer, schedulers=[warmup_scheduler, cosine_scheduler], milestones=[5])


# Train the model
train(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs, patience, save_dir)

# Test the model
test(model, test_loader)
# Out:
# Epoch 1/200, Train Loss: 1.7874, Train Acc: 33.92%, Val Loss: 1.5252, Val Acc: 44.20%
# Best model saved (based on val_acc = 44.20%)!
# Epoch 2/200, Train Loss: 1.4275, Train Acc: 48.33%, Val Loss: 1.4562, Val Acc: 49.96%
# Best model saved (based on val_acc = 49.96%)!
# Epoch 3/200, Train Loss: 1.1612, Train Acc: 58.55%, Val Loss: 1.0614, Val Acc: 61.74%
# Best model saved (based on val_acc = 61.74%)!
# Epoch 4/200, Train Loss: 0.9705, Train Acc: 65.95%, Val Loss: 1.0456, Val Acc: 64.52%
# Best model saved (based on val_acc = 64.52%)!
# /home/chungmop/.local/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:232: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 5/200, Train Loss: 0.8637, Train Acc: 70.25%, Val Loss: 0.9723, Val Acc: 66.30%
# Best model saved (based on val_acc = 66.30%)!
# Epoch 6/200, Train Loss: 0.8041, Train Acc: 72.09%, Val Loss: 0.9667, Val Acc: 68.84%
# Best model saved (based on val_acc = 68.84%)!
# Epoch 7/200, Train Loss: 0.7395, Train Acc: 74.49%, Val Loss: 0.7535, Val Acc: 74.16%
# Best model saved (based on val_acc = 74.16%)!
# Epoch 8/200, Train Loss: 0.6971, Train Acc: 75.75%, Val Loss: 0.9112, Val Acc: 70.48%
# Epoch 9/200, Train Loss: 0.6634, Train Acc: 76.98%, Val Loss: 0.6933, Val Acc: 76.06%
# Best model saved (based on val_acc = 76.06%)!
# Epoch 10/200, Train Loss: 0.6426, Train Acc: 77.75%, Val Loss: 0.8073, Val Acc: 72.96%
# Epoch 11/200, Train Loss: 0.6271, Train Acc: 78.42%, Val Loss: 0.6889, Val Acc: 76.46%
# Best model saved (based on val_acc = 76.46%)!
# Epoch 12/200, Train Loss: 0.6112, Train Acc: 78.91%, Val Loss: 0.7610, Val Acc: 74.22%
# Epoch 13/200, Train Loss: 0.6014, Train Acc: 79.18%, Val Loss: 0.7039, Val Acc: 75.30%
# Epoch 14/200, Train Loss: 0.5885, Train Acc: 79.75%, Val Loss: 0.7640, Val Acc: 73.72%
# Epoch 15/200, Train Loss: 0.5803, Train Acc: 79.88%, Val Loss: 0.6579, Val Acc: 77.36%
# Best model saved (based on val_acc = 77.36%)!
# Epoch 16/200, Train Loss: 0.5724, Train Acc: 80.30%, Val Loss: 0.6909, Val Acc: 76.06%
# Epoch 17/200, Train Loss: 0.5670, Train Acc: 80.61%, Val Loss: 0.6680, Val Acc: 76.86%
# Epoch 18/200, Train Loss: 0.5627, Train Acc: 80.47%, Val Loss: 0.8251, Val Acc: 71.76%
# Epoch 19/200, Train Loss: 0.5544, Train Acc: 80.68%, Val Loss: 0.7661, Val Acc: 73.68%
# Epoch 20/200, Train Loss: 0.5500, Train Acc: 80.79%, Val Loss: 0.5853, Val Acc: 79.88%
# Best model saved (based on val_acc = 79.88%)!
# Epoch 21/200, Train Loss: 0.5430, Train Acc: 81.26%, Val Loss: 0.7556, Val Acc: 75.06%
# Epoch 22/200, Train Loss: 0.5406, Train Acc: 81.46%, Val Loss: 0.8114, Val Acc: 72.54%
# Epoch 23/200, Train Loss: 0.5366, Train Acc: 81.43%, Val Loss: 0.9132, Val Acc: 70.96%
# Epoch 24/200, Train Loss: 0.5293, Train Acc: 81.54%, Val Loss: 0.7390, Val Acc: 74.18%
# Epoch 25/200, Train Loss: 0.5276, Train Acc: 81.72%, Val Loss: 0.7074, Val Acc: 75.92%
# Epoch 26/200, Train Loss: 0.5222, Train Acc: 81.91%, Val Loss: 0.7174, Val Acc: 76.16%
# Epoch 27/200, Train Loss: 0.5133, Train Acc: 82.16%, Val Loss: 0.7307, Val Acc: 74.80%
# Epoch 28/200, Train Loss: 0.5168, Train Acc: 82.00%, Val Loss: 0.7987, Val Acc: 73.10%
# Epoch 29/200, Train Loss: 0.5116, Train Acc: 82.44%, Val Loss: 0.8032, Val Acc: 72.56%
# Epoch 30/200, Train Loss: 0.5008, Train Acc: 82.63%, Val Loss: 0.6468, Val Acc: 79.28%
# Epoch 31/200, Train Loss: 0.4975, Train Acc: 82.79%, Val Loss: 0.7722, Val Acc: 75.58%
# Epoch 32/200, Train Loss: 0.4956, Train Acc: 82.96%, Val Loss: 0.6693, Val Acc: 77.26%
# Epoch 33/200, Train Loss: 0.4984, Train Acc: 82.68%, Val Loss: 0.7233, Val Acc: 76.20%
# Epoch 34/200, Train Loss: 0.4877, Train Acc: 83.24%, Val Loss: 0.6598, Val Acc: 77.56%
# Epoch 35/200, Train Loss: 0.4887, Train Acc: 83.08%, Val Loss: 0.7795, Val Acc: 74.70%
# Epoch 36/200, Train Loss: 0.4850, Train Acc: 83.25%, Val Loss: 0.6340, Val Acc: 78.72%
# Epoch 37/200, Train Loss: 0.4813, Train Acc: 83.21%, Val Loss: 0.6703, Val Acc: 77.52%
# Epoch 38/200, Train Loss: 0.4794, Train Acc: 83.41%, Val Loss: 0.5930, Val Acc: 80.56%
# Best model saved (based on val_acc = 80.56%)!
# Epoch 39/200, Train Loss: 0.4758, Train Acc: 83.57%, Val Loss: 0.6187, Val Acc: 77.78%
# Epoch 40/200, Train Loss: 0.4751, Train Acc: 83.53%, Val Loss: 0.7183, Val Acc: 76.36%
# Epoch 41/200, Train Loss: 0.4692, Train Acc: 83.96%, Val Loss: 0.6176, Val Acc: 79.00%
# Epoch 42/200, Train Loss: 0.4659, Train Acc: 83.96%, Val Loss: 0.6671, Val Acc: 78.14%
# Epoch 43/200, Train Loss: 0.4696, Train Acc: 83.55%, Val Loss: 0.7431, Val Acc: 75.82%
# Epoch 44/200, Train Loss: 0.4694, Train Acc: 83.62%, Val Loss: 0.7877, Val Acc: 73.16%
# Epoch 45/200, Train Loss: 0.4543, Train Acc: 84.28%, Val Loss: 0.6542, Val Acc: 78.14%
# Epoch 46/200, Train Loss: 0.4539, Train Acc: 84.26%, Val Loss: 0.5563, Val Acc: 81.46%
# Best model saved (based on val_acc = 81.46%)!
# Epoch 47/200, Train Loss: 0.4540, Train Acc: 84.30%, Val Loss: 0.5583, Val Acc: 81.38%
# Epoch 48/200, Train Loss: 0.4524, Train Acc: 84.38%, Val Loss: 0.5693, Val Acc: 79.44%
# Epoch 49/200, Train Loss: 0.4469, Train Acc: 84.56%, Val Loss: 0.6389, Val Acc: 78.92%
# Epoch 50/200, Train Loss: 0.4464, Train Acc: 84.44%, Val Loss: 0.5796, Val Acc: 80.12%
# Epoch 51/200, Train Loss: 0.4474, Train Acc: 84.56%, Val Loss: 0.6240, Val Acc: 79.76%
# Epoch 52/200, Train Loss: 0.4423, Train Acc: 84.72%, Val Loss: 0.6175, Val Acc: 79.86%
# Epoch 53/200, Train Loss: 0.4392, Train Acc: 84.73%, Val Loss: 0.7075, Val Acc: 77.52%
# Epoch 54/200, Train Loss: 0.4368, Train Acc: 84.95%, Val Loss: 0.6380, Val Acc: 79.78%
# Epoch 55/200, Train Loss: 0.4286, Train Acc: 85.33%, Val Loss: 0.7894, Val Acc: 76.08%
# Epoch 56/200, Train Loss: 0.4348, Train Acc: 84.92%, Val Loss: 0.6481, Val Acc: 78.22%
# Epoch 57/200, Train Loss: 0.4276, Train Acc: 85.21%, Val Loss: 0.5993, Val Acc: 79.44%
# Epoch 58/200, Train Loss: 0.4289, Train Acc: 85.15%, Val Loss: 0.7924, Val Acc: 74.96%
# Epoch 59/200, Train Loss: 0.4325, Train Acc: 85.06%, Val Loss: 0.7995, Val Acc: 74.12%
# Epoch 60/200, Train Loss: 0.4211, Train Acc: 85.37%, Val Loss: 0.6459, Val Acc: 78.52%
# Epoch 61/200, Train Loss: 0.4251, Train Acc: 85.40%, Val Loss: 0.7231, Val Acc: 77.22%
# Epoch 62/200, Train Loss: 0.4187, Train Acc: 85.49%, Val Loss: 0.6568, Val Acc: 77.08%
# Epoch 63/200, Train Loss: 0.4139, Train Acc: 85.73%, Val Loss: 0.6723, Val Acc: 77.66%
# Epoch 64/200, Train Loss: 0.4113, Train Acc: 85.70%, Val Loss: 0.6537, Val Acc: 79.22%
# Epoch 65/200, Train Loss: 0.4122, Train Acc: 85.69%, Val Loss: 0.8419, Val Acc: 73.58%
# Epoch 66/200, Train Loss: 0.4145, Train Acc: 85.64%, Val Loss: 0.5332, Val Acc: 81.88%
# Best model saved (based on val_acc = 81.88%)!
# Epoch 67/200, Train Loss: 0.4052, Train Acc: 85.91%, Val Loss: 0.5300, Val Acc: 81.98%
# Best model saved (based on val_acc = 81.98%)!
# Epoch 68/200, Train Loss: 0.4032, Train Acc: 86.08%, Val Loss: 0.6122, Val Acc: 79.44%
# Epoch 69/200, Train Loss: 0.3997, Train Acc: 86.11%, Val Loss: 0.4903, Val Acc: 82.72%
# Best model saved (based on val_acc = 82.72%)!
# Epoch 70/200, Train Loss: 0.4036, Train Acc: 86.05%, Val Loss: 0.5159, Val Acc: 81.92%
# Epoch 71/200, Train Loss: 0.3988, Train Acc: 86.30%, Val Loss: 0.4826, Val Acc: 83.30%
# Best model saved (based on val_acc = 83.30%)!
# Epoch 72/200, Train Loss: 0.3902, Train Acc: 86.56%, Val Loss: 0.6065, Val Acc: 79.38%
# Epoch 73/200, Train Loss: 0.3957, Train Acc: 86.39%, Val Loss: 0.5463, Val Acc: 81.42%
# Epoch 74/200, Train Loss: 0.3920, Train Acc: 86.44%, Val Loss: 0.6157, Val Acc: 79.64%
# Epoch 75/200, Train Loss: 0.3919, Train Acc: 86.19%, Val Loss: 0.6064, Val Acc: 79.36%
# Epoch 76/200, Train Loss: 0.3879, Train Acc: 86.50%, Val Loss: 0.6174, Val Acc: 80.94%
# Epoch 77/200, Train Loss: 0.3847, Train Acc: 86.62%, Val Loss: 0.4553, Val Acc: 84.14%
# Best model saved (based on val_acc = 84.14%)!
# Epoch 78/200, Train Loss: 0.3793, Train Acc: 86.85%, Val Loss: 0.5471, Val Acc: 81.92%
# Epoch 79/200, Train Loss: 0.3815, Train Acc: 86.94%, Val Loss: 0.5523, Val Acc: 81.14%
# Epoch 80/200, Train Loss: 0.3743, Train Acc: 86.91%, Val Loss: 0.4608, Val Acc: 84.54%
# Best model saved (based on val_acc = 84.54%)!
# Epoch 81/200, Train Loss: 0.3724, Train Acc: 86.96%, Val Loss: 0.5249, Val Acc: 82.74%
# Epoch 82/200, Train Loss: 0.3676, Train Acc: 87.44%, Val Loss: 0.6030, Val Acc: 80.10%
# Epoch 83/200, Train Loss: 0.3719, Train Acc: 87.04%, Val Loss: 0.4821, Val Acc: 83.72%
# Epoch 84/200, Train Loss: 0.3562, Train Acc: 87.67%, Val Loss: 0.5146, Val Acc: 82.96%
# Epoch 85/200, Train Loss: 0.3645, Train Acc: 87.32%, Val Loss: 0.5095, Val Acc: 82.78%
# Epoch 86/200, Train Loss: 0.3661, Train Acc: 87.33%, Val Loss: 0.5148, Val Acc: 81.68%
# Epoch 87/200, Train Loss: 0.3559, Train Acc: 87.75%, Val Loss: 0.5502, Val Acc: 82.38%
# Epoch 88/200, Train Loss: 0.3575, Train Acc: 87.62%, Val Loss: 0.5019, Val Acc: 83.26%
# Epoch 89/200, Train Loss: 0.3532, Train Acc: 87.68%, Val Loss: 0.4725, Val Acc: 83.62%
# Epoch 90/200, Train Loss: 0.3478, Train Acc: 87.84%, Val Loss: 0.4731, Val Acc: 83.74%
# Epoch 91/200, Train Loss: 0.3493, Train Acc: 87.84%, Val Loss: 0.4571, Val Acc: 84.58%
# Best model saved (based on val_acc = 84.58%)!
# Epoch 92/200, Train Loss: 0.3381, Train Acc: 88.43%, Val Loss: 0.4946, Val Acc: 83.04%
# Epoch 93/200, Train Loss: 0.3407, Train Acc: 88.20%, Val Loss: 0.4496, Val Acc: 84.82%
# Best model saved (based on val_acc = 84.82%)!
# Epoch 94/200, Train Loss: 0.3408, Train Acc: 88.13%, Val Loss: 0.4855, Val Acc: 83.72%
# Epoch 95/200, Train Loss: 0.3356, Train Acc: 88.37%, Val Loss: 0.4400, Val Acc: 85.14%
# Best model saved (based on val_acc = 85.14%)!
# Epoch 96/200, Train Loss: 0.3264, Train Acc: 88.69%, Val Loss: 0.4652, Val Acc: 84.26%
# Epoch 97/200, Train Loss: 0.3296, Train Acc: 88.69%, Val Loss: 0.5124, Val Acc: 83.40%
# Epoch 98/200, Train Loss: 0.3210, Train Acc: 88.88%, Val Loss: 0.5188, Val Acc: 82.28%
# Epoch 99/200, Train Loss: 0.3215, Train Acc: 88.79%, Val Loss: 0.4507, Val Acc: 84.38%
# Epoch 100/200, Train Loss: 0.3257, Train Acc: 88.74%, Val Loss: 0.5207, Val Acc: 82.24%
# Epoch 101/200, Train Loss: 0.3169, Train Acc: 89.08%, Val Loss: 0.4391, Val Acc: 84.94%
# Epoch 102/200, Train Loss: 0.3100, Train Acc: 89.23%, Val Loss: 0.4420, Val Acc: 85.50%
# Best model saved (based on val_acc = 85.50%)!
# Epoch 103/200, Train Loss: 0.3127, Train Acc: 89.26%, Val Loss: 0.4412, Val Acc: 85.26%
# Epoch 104/200, Train Loss: 0.3071, Train Acc: 89.35%, Val Loss: 0.4556, Val Acc: 84.54%
# Epoch 105/200, Train Loss: 0.3023, Train Acc: 89.55%, Val Loss: 0.5433, Val Acc: 81.48%
# Epoch 106/200, Train Loss: 0.2993, Train Acc: 89.68%, Val Loss: 0.5397, Val Acc: 83.12%
# Epoch 107/200, Train Loss: 0.2995, Train Acc: 89.51%, Val Loss: 0.4536, Val Acc: 84.62%
# Epoch 108/200, Train Loss: 0.2973, Train Acc: 89.59%, Val Loss: 0.4620, Val Acc: 84.96%
# Epoch 109/200, Train Loss: 0.2904, Train Acc: 89.93%, Val Loss: 0.4213, Val Acc: 84.80%
# Epoch 110/200, Train Loss: 0.2938, Train Acc: 89.68%, Val Loss: 0.4316, Val Acc: 85.50%
# Epoch 111/200, Train Loss: 0.2845, Train Acc: 90.05%, Val Loss: 0.4236, Val Acc: 85.36%
# Epoch 112/200, Train Loss: 0.2817, Train Acc: 90.30%, Val Loss: 0.4649, Val Acc: 83.92%
# Epoch 113/200, Train Loss: 0.2825, Train Acc: 90.23%, Val Loss: 0.3737, Val Acc: 86.74%
# Best model saved (based on val_acc = 86.74%)!
# Epoch 114/200, Train Loss: 0.2731, Train Acc: 90.54%, Val Loss: 0.3934, Val Acc: 86.82%
# Best model saved (based on val_acc = 86.82%)!
# Epoch 115/200, Train Loss: 0.2780, Train Acc: 90.40%, Val Loss: 0.4158, Val Acc: 85.76%
# Epoch 116/200, Train Loss: 0.2658, Train Acc: 90.72%, Val Loss: 0.4186, Val Acc: 85.94%
# Epoch 117/200, Train Loss: 0.2626, Train Acc: 90.76%, Val Loss: 0.4119, Val Acc: 86.08%
# Epoch 118/200, Train Loss: 0.2677, Train Acc: 90.60%, Val Loss: 0.4387, Val Acc: 85.44%
# Epoch 119/200, Train Loss: 0.2577, Train Acc: 91.06%, Val Loss: 0.4427, Val Acc: 84.60%
# Epoch 120/200, Train Loss: 0.2548, Train Acc: 91.17%, Val Loss: 0.4516, Val Acc: 85.88%
# Epoch 121/200, Train Loss: 0.2496, Train Acc: 91.30%, Val Loss: 0.4035, Val Acc: 86.92%
# Best model saved (based on val_acc = 86.92%)!
# Epoch 122/200, Train Loss: 0.2496, Train Acc: 91.39%, Val Loss: 0.3436, Val Acc: 88.36%
# Best model saved (based on val_acc = 88.36%)!
# Epoch 123/200, Train Loss: 0.2432, Train Acc: 91.48%, Val Loss: 0.3647, Val Acc: 88.06%
# Epoch 124/200, Train Loss: 0.2394, Train Acc: 91.71%, Val Loss: 0.3580, Val Acc: 87.86%
# Epoch 125/200, Train Loss: 0.2348, Train Acc: 91.80%, Val Loss: 0.4091, Val Acc: 86.68%
# Epoch 126/200, Train Loss: 0.2325, Train Acc: 91.98%, Val Loss: 0.3373, Val Acc: 88.44%
# Best model saved (based on val_acc = 88.44%)!
# Epoch 127/200, Train Loss: 0.2209, Train Acc: 92.35%, Val Loss: 0.3779, Val Acc: 87.32%
# Epoch 128/200, Train Loss: 0.2242, Train Acc: 92.19%, Val Loss: 0.3680, Val Acc: 88.10%
# Epoch 129/200, Train Loss: 0.2200, Train Acc: 92.26%, Val Loss: 0.4618, Val Acc: 85.18%
# Epoch 130/200, Train Loss: 0.2220, Train Acc: 92.28%, Val Loss: 0.3580, Val Acc: 87.84%
# Epoch 131/200, Train Loss: 0.2132, Train Acc: 92.56%, Val Loss: 0.3889, Val Acc: 87.64%
# Epoch 132/200, Train Loss: 0.2151, Train Acc: 92.47%, Val Loss: 0.3539, Val Acc: 88.22%
# Epoch 133/200, Train Loss: 0.1992, Train Acc: 93.03%, Val Loss: 0.3281, Val Acc: 88.72%
# Best model saved (based on val_acc = 88.72%)!
# Epoch 134/200, Train Loss: 0.2017, Train Acc: 92.97%, Val Loss: 0.3015, Val Acc: 90.02%
# Best model saved (based on val_acc = 90.02%)!
# Epoch 135/200, Train Loss: 0.1991, Train Acc: 93.08%, Val Loss: 0.4164, Val Acc: 86.00%
# Epoch 136/200, Train Loss: 0.1940, Train Acc: 93.33%, Val Loss: 0.3131, Val Acc: 89.04%
# Epoch 137/200, Train Loss: 0.1890, Train Acc: 93.41%, Val Loss: 0.3304, Val Acc: 88.88%
# Epoch 138/200, Train Loss: 0.1855, Train Acc: 93.47%, Val Loss: 0.3265, Val Acc: 88.96%
# Epoch 139/200, Train Loss: 0.1837, Train Acc: 93.57%, Val Loss: 0.3326, Val Acc: 89.74%
# Epoch 140/200, Train Loss: 0.1764, Train Acc: 93.83%, Val Loss: 0.3559, Val Acc: 88.26%
# Epoch 141/200, Train Loss: 0.1740, Train Acc: 93.88%, Val Loss: 0.3717, Val Acc: 87.74%
# Epoch 142/200, Train Loss: 0.1712, Train Acc: 94.04%, Val Loss: 0.3254, Val Acc: 89.92%
# Epoch 143/200, Train Loss: 0.1655, Train Acc: 94.14%, Val Loss: 0.3200, Val Acc: 89.62%
# Epoch 144/200, Train Loss: 0.1582, Train Acc: 94.38%, Val Loss: 0.3322, Val Acc: 89.20%
# Epoch 145/200, Train Loss: 0.1551, Train Acc: 94.56%, Val Loss: 0.3253, Val Acc: 89.56%
# Epoch 146/200, Train Loss: 0.1501, Train Acc: 94.80%, Val Loss: 0.2961, Val Acc: 89.90%
# Epoch 147/200, Train Loss: 0.1488, Train Acc: 94.69%, Val Loss: 0.3352, Val Acc: 88.98%
# Epoch 148/200, Train Loss: 0.1402, Train Acc: 95.11%, Val Loss: 0.2836, Val Acc: 91.02%
# Best model saved (based on val_acc = 91.02%)!
# Epoch 149/200, Train Loss: 0.1393, Train Acc: 95.25%, Val Loss: 0.2873, Val Acc: 90.32%
# Epoch 150/200, Train Loss: 0.1292, Train Acc: 95.45%, Val Loss: 0.2898, Val Acc: 90.56%
# Epoch 151/200, Train Loss: 0.1290, Train Acc: 95.48%, Val Loss: 0.3168, Val Acc: 90.36%
# Epoch 152/200, Train Loss: 0.1270, Train Acc: 95.64%, Val Loss: 0.2714, Val Acc: 91.02%
# Epoch 153/200, Train Loss: 0.1198, Train Acc: 95.82%, Val Loss: 0.2850, Val Acc: 90.50%
# Epoch 154/200, Train Loss: 0.1165, Train Acc: 95.98%, Val Loss: 0.2884, Val Acc: 91.14%
# Best model saved (based on val_acc = 91.14%)!
# Epoch 155/200, Train Loss: 0.1118, Train Acc: 96.13%, Val Loss: 0.2934, Val Acc: 91.26%
# Best model saved (based on val_acc = 91.26%)!
# Epoch 156/200, Train Loss: 0.1068, Train Acc: 96.31%, Val Loss: 0.2594, Val Acc: 91.90%
# Best model saved (based on val_acc = 91.90%)!
# Epoch 157/200, Train Loss: 0.1008, Train Acc: 96.54%, Val Loss: 0.2709, Val Acc: 91.24%
# Epoch 158/200, Train Loss: 0.1003, Train Acc: 96.59%, Val Loss: 0.2706, Val Acc: 91.30%
# Epoch 159/200, Train Loss: 0.0980, Train Acc: 96.65%, Val Loss: 0.2538, Val Acc: 91.94%
# Best model saved (based on val_acc = 91.94%)!
# Epoch 160/200, Train Loss: 0.0914, Train Acc: 96.91%, Val Loss: 0.2449, Val Acc: 92.10%
# Best model saved (based on val_acc = 92.10%)!
# Epoch 161/200, Train Loss: 0.0821, Train Acc: 97.20%, Val Loss: 0.2679, Val Acc: 91.72%
# Epoch 162/200, Train Loss: 0.0812, Train Acc: 97.25%, Val Loss: 0.2530, Val Acc: 92.12%
# Best model saved (based on val_acc = 92.12%)!
# Epoch 163/200, Train Loss: 0.0792, Train Acc: 97.27%, Val Loss: 0.2548, Val Acc: 92.50%
# Best model saved (based on val_acc = 92.50%)!
# Epoch 164/200, Train Loss: 0.0788, Train Acc: 97.36%, Val Loss: 0.2614, Val Acc: 91.78%
# Epoch 165/200, Train Loss: 0.0715, Train Acc: 97.58%, Val Loss: 0.2379, Val Acc: 92.52%
# Best model saved (based on val_acc = 92.52%)!
# Epoch 166/200, Train Loss: 0.0664, Train Acc: 97.73%, Val Loss: 0.2356, Val Acc: 92.66%
# Best model saved (based on val_acc = 92.66%)!
# Epoch 167/200, Train Loss: 0.0609, Train Acc: 97.93%, Val Loss: 0.2327, Val Acc: 92.66%
# Epoch 168/200, Train Loss: 0.0611, Train Acc: 98.00%, Val Loss: 0.2394, Val Acc: 92.48%
# Epoch 169/200, Train Loss: 0.0569, Train Acc: 98.06%, Val Loss: 0.2275, Val Acc: 92.66%
# Epoch 170/200, Train Loss: 0.0520, Train Acc: 98.29%, Val Loss: 0.2265, Val Acc: 93.10%
# Best model saved (based on val_acc = 93.10%)!
# Epoch 171/200, Train Loss: 0.0503, Train Acc: 98.36%, Val Loss: 0.2325, Val Acc: 92.80%
# Epoch 172/200, Train Loss: 0.0461, Train Acc: 98.40%, Val Loss: 0.2064, Val Acc: 93.50%
# Best model saved (based on val_acc = 93.50%)!
# Epoch 173/200, Train Loss: 0.0447, Train Acc: 98.52%, Val Loss: 0.2073, Val Acc: 93.38%
# Epoch 174/200, Train Loss: 0.0423, Train Acc: 98.62%, Val Loss: 0.2181, Val Acc: 93.52%
# Best model saved (based on val_acc = 93.52%)!
# Epoch 175/200, Train Loss: 0.0395, Train Acc: 98.70%, Val Loss: 0.1960, Val Acc: 93.66%
# Best model saved (based on val_acc = 93.66%)!
# Epoch 176/200, Train Loss: 0.0349, Train Acc: 98.87%, Val Loss: 0.2000, Val Acc: 94.08%
# Best model saved (based on val_acc = 94.08%)!
# Epoch 177/200, Train Loss: 0.0317, Train Acc: 99.03%, Val Loss: 0.1889, Val Acc: 94.28%
# Best model saved (based on val_acc = 94.28%)!
# Epoch 178/200, Train Loss: 0.0354, Train Acc: 98.87%, Val Loss: 0.2225, Val Acc: 93.80%
# Epoch 179/200, Train Loss: 0.0318, Train Acc: 98.96%, Val Loss: 0.1878, Val Acc: 94.18%
# Epoch 180/200, Train Loss: 0.0287, Train Acc: 99.10%, Val Loss: 0.1957, Val Acc: 93.96%
# Epoch 181/200, Train Loss: 0.0283, Train Acc: 99.05%, Val Loss: 0.1828, Val Acc: 94.46%
# Best model saved (based on val_acc = 94.46%)!
# Epoch 182/200, Train Loss: 0.0274, Train Acc: 99.12%, Val Loss: 0.1901, Val Acc: 94.20%
# Epoch 183/200, Train Loss: 0.0256, Train Acc: 99.22%, Val Loss: 0.1969, Val Acc: 94.20%
# Epoch 184/200, Train Loss: 0.0252, Train Acc: 99.21%, Val Loss: 0.1963, Val Acc: 93.98%
# Epoch 185/200, Train Loss: 0.0235, Train Acc: 99.24%, Val Loss: 0.2063, Val Acc: 93.76%
# Epoch 186/200, Train Loss: 0.0251, Train Acc: 99.21%, Val Loss: 0.1969, Val Acc: 94.46%
# Epoch 187/200, Train Loss: 0.0217, Train Acc: 99.31%, Val Loss: 0.1973, Val Acc: 94.46%
# Epoch 188/200, Train Loss: 0.0224, Train Acc: 99.32%, Val Loss: 0.1884, Val Acc: 94.78%
# Best model saved (based on val_acc = 94.78%)!
# Epoch 189/200, Train Loss: 0.0217, Train Acc: 99.35%, Val Loss: 0.1708, Val Acc: 94.58%
# Epoch 190/200, Train Loss: 0.0193, Train Acc: 99.43%, Val Loss: 0.1718, Val Acc: 95.14%
# Best model saved (based on val_acc = 95.14%)!
# Epoch 191/200, Train Loss: 0.0201, Train Acc: 99.40%, Val Loss: 0.1714, Val Acc: 94.56%
# Epoch 192/200, Train Loss: 0.0206, Train Acc: 99.40%, Val Loss: 0.1775, Val Acc: 94.78%
# Epoch 193/200, Train Loss: 0.0197, Train Acc: 99.40%, Val Loss: 0.1787, Val Acc: 94.84%
# Epoch 194/200, Train Loss: 0.0167, Train Acc: 99.51%, Val Loss: 0.1788, Val Acc: 94.74%
# Epoch 195/200, Train Loss: 0.0173, Train Acc: 99.46%, Val Loss: 0.1758, Val Acc: 94.82%
# Epoch 196/200, Train Loss: 0.0181, Train Acc: 99.48%, Val Loss: 0.1822, Val Acc: 94.98%
# Epoch 197/200, Train Loss: 0.0179, Train Acc: 99.45%, Val Loss: 0.1855, Val Acc: 94.58%
# Epoch 198/200, Train Loss: 0.0169, Train Acc: 99.53%, Val Loss: 0.1695, Val Acc: 94.80%
# Epoch 199/200, Train Loss: 0.0185, Train Acc: 99.46%, Val Loss: 0.1942, Val Acc: 94.58%
# Epoch 200/200, Train Loss: 0.0169, Train Acc: 99.53%, Val Loss: 0.1665, Val Acc: 94.84%
# Test Accuracy: 96.25%

# %% [markdown]
# # Save Model

# %%
PreActResNet152_2_model = model

# %%
torch.save(PreActResNet152_2_model.state_dict(), "PreActResNet152_2_model.pth")

# %% [markdown]
# # Run Kaggal Test

# %%
import pickle
import numpy as np
import torch
from PIL import Image
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms

# Load the test dataset
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Load the no-label test dataset
test_data = unpickle("deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/cifar_test_nolabel.pkl")

# Extract image data and IDs
test_images = test_data[b'data']  # Shape (N, 3072)
test_ids = test_data[b'ids']  # Image IDs for submission

# %%
test_images = test_images.transpose(0,3,1,2)
# test_images.shape

# %%
# Reshape to (N, 3, 32, 32)
# test_images = test_images.reshape(-1, 3, 32, 32).astype(np.uint8)
# test_images = test_images.transpose(0,3,2,1)
class TestCIFARDataset(Dataset):
    def __init__(self, images, transform=None):
        self.images = images
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        image = Image.fromarray(np.transpose(image, (1, 2, 0)))  # Convert (C, H, W) → (H, W, C)

        if self.transform:
            image = self.transform(image)

        return image

# Define test transforms (same as training but without augmentation)
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# Create DataLoader for inference
test_dataset = TestCIFARDataset(test_images, transform=transform_test)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False, num_workers=8, pin_memory=True)

# %%
def run_inference(model, test_loader, device):
    model.eval()
    predictions = []

    with torch.no_grad():  # Disable gradients for faster inference
        for images in test_loader:
            images = images.to(device)

            outputs = model(images)
            _, predicted = outputs.max(1)  # Get the class index with max probability
            predictions.extend(predicted.cpu().numpy())  # Move to CPU for saving

    return predictions

# %%
import pandas as pd

# Run inference
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
predictions = run_inference(model, test_loader, device)

# Create a DataFrame
submission_df = pd.DataFrame({'ID': test_ids, 'Labels': predictions})

# Save to CSV (without index column)
submission_df.to_csv("newopt_resnet10.csv", index=False)

print("Submission file saved as submission.csv")
# Out:
# Submission file saved as submission.csv
